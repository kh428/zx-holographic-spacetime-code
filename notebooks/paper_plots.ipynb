p_L_big = [[0.249267578125, 0.268310546875, 0.28564453125, 0.302978515625, 0.3232421875, 0.345947265625, 0.365234375, 0.38623046875, 0.3984375, 0.41552734375, 0.4345703125, 0.45166015625, 0.470458984375, 0.486083984375, 0.503173828125, 0.5205078125, 0.537353515625, 0.552734375, 0.56787109375, 0.58935546875], [0.540283203125, 0.571044921875, 0.59423828125, 0.6240234375, 0.639892578125, 0.65234375, 0.669677734375, 0.681640625, 0.69580078125, 0.703369140625, 0.705810546875, 0.707763671875, 0.71044921875, 0.717041015625, 0.725341796875, 0.734130859375, 0.7333984375, 0.73974609375, 0.752685546875, 0.747314453125], [0.73974609375, 0.74462890625, 0.746826171875, 0.73681640625, 0.73828125, 0.751220703125, 0.740478515625, 0.748291015625, 0.750244140625, 0.756103515625, 0.7568359375, 0.751953125, 0.74951171875, 0.753173828125, 0.748291015625, 0.743896484375, 0.740966796875, 0.74560546875, 0.762451171875, 0.75927734375], 
        #  # wrong used the cached one instead...  [0.2265625, 0.283935546875, 0.360595703125, 0.443603515625, 0.516845703125, 0.574462890625, 0.621826171875, 0.678955078125, 0.707275390625, 0.733642578125, 0.7373046875, 0.728271484375, 0.762939453125, 0.752685546875, 0.764892578125, 0.75537109375, 0.7509765625, 0.7490234375, 0.74462890625, 0.745849609375]
           [0.748779296875, 0.7529296875, 0.7548828125, 0.75146484375, 0.7578125, 0.7373046875, 0.7490234375, 0.759033203125, 0.749755859375, 0.74609375, 0.756103515625, 0.74951171875, 0.749267578125, 0.7509765625, 0.7451171875, 0.752685546875, 0.752197265625, 0.751220703125, 0.75732421875, 0.77294921875]
           ]
num_shots_range = [[4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096], [4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096], [4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096], [4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096, 4096]]

fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","cyan","magenta","yellow"]
strlst = [f"$n={n}$" for n in ns]

for ct in range(len(ns)):
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    num_shots = num_shots_range[ct]
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
    ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])
    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"erasure rate, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BP decoder - 50 max. iterations",fontsize=10)
# ax.set_xlim(right = 0.51)
# ax.set_ylim(bottom = 1e-4)
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192], [8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192], [8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192], [8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192]]

p_phy_big = [ii+jj for ii,jj in zip(p_phy_big,p_phy_big2)]
p_L_big = [ii+jj for ii,jj in zip(p_L_big,p_L_big2)]
num_shots_range = [ii+jj for ii,jj in zip(num_shots_range,num_shots_range2)]



fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","cyan","magenta","yellow"]
strlst = [f"$n={n}$" for n in ns]

for ct in range(len(ns)):
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    num_shots = num_shots_range[ct]
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
    ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])
    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"erasure probability, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BP decoder - 50 max. iterations, $|{0}\rangle^{\otimes (N_\text{bulk}-1)}$ gauge",fontsize=7.5)
# ax.set_xlim(right = 0.51)
# ax.set_ylim(bottom = 1e-4)
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ns = [0,1,2,3]

p_phy_big = [np.linspace(0.3, 0.6, 20).tolist()]*(len(ns))
p_L_big =[[0.249267578125, 0.268310546875, 0.28564453125, 0.302978515625, 0.3232421875, 0.345947265625, 0.365234375, 0.38623046875, 0.3984375, 0.41552734375, 0.4345703125, 0.45166015625, 0.470458984375, 0.486083984375, 0.503173828125, 0.5205078125, 0.537353515625, 0.552734375, 0.56787109375, 0.58935546875], 
          [0.14990234375, 0.1689453125, 0.1923828125, 0.21875, 0.245849609375, 0.279052734375, 0.304931640625, 0.34033203125, 0.372802734375, 0.409912109375, 0.448974609375, 0.477783203125, 0.50537109375, 0.53125, 0.556396484375, 0.589599609375, 0.616455078125, 0.6298828125, 0.658447265625, 0.6767578125], 
          [0.08349609375, 0.107421875, 0.146240234375, 0.170654296875, 0.204833984375, 0.2548828125, 0.2978515625, 0.340576171875, 0.393310546875, 0.44970703125, 0.501953125, 0.53955078125, 0.59912109375, 0.627197265625, 0.64990234375, 0.68212890625, 0.6943359375, 0.711181640625, 0.718505859375, 0.71923828125], 
          [0.2265625, 0.283935546875, 0.360595703125, 0.443603515625, 0.516845703125, 0.574462890625, 0.621826171875, 0.678955078125, 0.707275390625, 0.733642578125, 0.7373046875, 0.728271484375, 0.762939453125, 0.752685546875, 0.764892578125, 0.75537109375, 0.7509765625, 0.7490234375, 0.74462890625, 0.745849609375]]
num_shots_range = [[2**12]*len(p_phy_big[0])]*len(ns)

p_phy_big = p_phy_big + [[0.3000,0.3158,0.3316,0.3474,0.3632,0.3789,0.3947,0.4, 0.4222222222222222, 0.4444444444444445, 0.4666666666666667, 0.4888888888888889, 0.5111111111111111, 0.5333333333333333, 0.5555555555555556, 0.5777777777777777, 0.6]]
p_L_big = p_L_big + [[6.726074e-01,7.180176e-01,7.329102e-01,7.629395e-01,7.558594e-01,7.490234e-01,7.531738e-01,0.7734375, 0.7890625, 0.70703125, 0.73046875, 0.75390625, 0.75, 0.76171875, 0.73046875, 0.73828125, 0.7265625]]
num_shots_range = num_shots_range + [[2**12]*7+[256]*10]
ns = [0,1,2,3,4]


p_L_big_new = [[0.125244140625, 0.146484375, 0.166748046875, 0.195068359375, 0.223876953125, 0.249267578125], [0.044921875, 0.059814453125, 0.073974609375, 0.097412109375, 0.123046875, 0.14990234375], [0.012451171875, 0.01806640625, 0.029052734375, 0.04296875, 0.06005859375, 0.08349609375], [0.034912109375, 0.050048828125, 0.072021484375, 0.10400390625, 0.1572265625, 0.2265625], [0.0849609375, 0.149658203125, 0.2548828125, 0.406982421875, 0.568603515625, 0.672607421875]]

p_phy_big = [np.linspace(0.2, 0.3, 6).tolist() + ii for ii in p_phy_big]
p_L_big = [ii+jj for ii, jj in zip(p_L_big_new,p_L_big)]
num_shots_range = [[2**12]*6 +  ii for ii in num_shots_range]

fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","cyan","magenta","yellow"]
strlst = [f"$n={n}$" for n in ns]

for ct in range(len(ns)):
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    num_shots = num_shots_range[ct]
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
    ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])
    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"erasure probability, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BP decoder - 50 max. iterations, $|{+}\rangle^{\otimes (N_\text{bulk}-1)}$ gauge",fontsize=7.5)
# ax.set_xlim(right = 0.51)
# ax.set_ylim(bottom = 1e-4)
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ns = [0,1,2,3,4]

p_phy_big = [[0.2, 0.2236842105263158, 0.2473684210526316, 0.2710526315789474, 0.2947368421052632, 0.31842105263157894, 0.34210526315789475, 0.36578947368421055, 0.3894736842105263, 0.4131578947368421, 0.4368421052631579, 0.46052631578947373, 0.4842105263157895, 0.5078947368421053, 0.5315789473684212, 0.5552631578947369, 0.5789473684210527, 0.6026315789473684, 0.6263157894736842, 0.65], 
             [0.2, 0.2236842105263158, 0.2473684210526316, 0.2710526315789474, 0.2947368421052632, 0.31842105263157894, 0.34210526315789475, 0.36578947368421055, 0.3894736842105263, 0.4131578947368421, 0.4368421052631579, 0.46052631578947373, 0.4842105263157895, 0.5078947368421053, 0.5315789473684212, 0.5552631578947369, 0.5789473684210527, 0.6026315789473684, 0.6263157894736842, 0.65], 
             [0.2, 0.22, 0.24, 0.26, 0.28, 0.3]+[0.31842105263157894, 0.34210526315789475, 0.36578947368421055, 0.3894736842105263, 0.4131578947368421, 0.4368421052631579, 0.46052631578947373, 0.4842105263157895, 0.5078947368421053, 0.5315789473684212, 0.5552631578947369, 0.5789473684210527, 0.6026315789473684, 0.6263157894736842, 0.65],
             [0.2500,0.2800,0.2900,0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6000000000000001, 0.625, 0.65],
             [0.4000, 0.4105, 0.4211, 0.4316, 0.4421, 0.4526,0.4632,0.4737,0.4842,0.4947,0.5053,0.5158,0.5263,0.5368,0.5474,0.5579,0.5684,0.5789,0.5895,0.6000,0.6250,0.650]
             ]

p_L_big = [[0.09619140625, 0.11761474609375, 0.140380859375, 0.165771484375, 0.1910400390625, 0.2169189453125, 0.24273681640625, 0.27081298828125, 0.29974365234375, 0.3260498046875, 0.3533935546875, 0.380615234375, 0.41015625, 0.43780517578125, 0.4622802734375, 0.488525390625, 0.5145263671875, 0.53900146484375, 0.560302734375, 0.58038330078125], 
           [0.01654052734375, 0.02703857421875, 0.03955078125, 0.0556640625, 0.07891845703125, 0.1070556640625, 0.13604736328125, 0.164794921875, 0.20404052734375, 0.24365234375, 0.29345703125, 0.33538818359375, 0.38360595703125, 0.42681884765625, 0.47613525390625, 0.521240234375, 0.5618896484375, 0.5943603515625, 0.6279296875, 0.6566162109375], 
           [0.0013275146484375, 0.00231170654296875, 0.004001617431640625, 0.0069580078125, 0.01122283935546875, 0.01825714111328125, 0.02593994140625, 0.04388427734375, 0.07073974609375, 0.107421875, 0.1566162109375, 0.2197265625, 0.2830810546875, 0.367431640625, 0.4373779296875, 0.5069580078125, 0.5758056640625, 0.62310791015625, 0.672607421875, 0.7049560546875, 0.720703125],
           [7/786432,6.103516e-05,1.182556e-04,1.983643e-04, 0.000732421875, 0.0028076171875, 0.009490966796875, 0.02679443359375, 0.0688934326171875, 0.149383544921875, 0.269805908203125, 0.41522216796875, 0.5542449951171875, 0.651397705078125, 0.7078857421875, 0.73724365234375, 0.7414398193359375, 0.7474517822265625],
           [9.765625e-04, 2.319336e-03, 5.615234e-03, 1.330566e-02, 2.893066e-02, 5.187988e-02,9.594727e-02,1.590576e-01,2.504883e-01,3.489990e-01,4.602051e-01,5.573730e-01,6.306152e-01,6.870117e-01,7.105713e-01,7.254639e-01,7.388916e-01,7.591553e-01,7.506104e-01,7.491455e-01,7.460938e-01,7.558594e-01]
           ]

num_shots_range = [[16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384], 
                   [16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384], 
                   [262144,262144,262144,262144,262144,262144, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384, 16384],
                   [786432]+[2**18]*3+[65536]*14,
                   [2**13]*20+[2**9]*2
                   ]

# 0.2500  p_depol=0.0000  p_L=1.144409e-05
# 0.2600  p_depol=0.0000  p_L=1.144409e-05
# n=3  p_erase=0.2700  p_depol=0.0000  p_L=2.670288e-05

# n=3  p_erase=0.2900  p_depol=0.0000  p_L=1.182556e-04
# n=3  p_erase=0.3000  p_depol=0.0000  p_L=1.983643e-04

fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","cyan","magenta","yellow"]
strlst = [f"$n={n}$" for n in ns]

for ct in range(len(ns)):
    # print(ct)
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    p_L[p_L<1e-10] = None
    num_shots = num_shots_range[ct]
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
    ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])
    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

# x = np.arange(0.1,0.4,0.0001)
# y = 2*x**2
# ax.plot(x, y, c="black",linestyle="-")
# y = 10*x**4
# ax.plot(x, y, c="black",linestyle="-")
# y = 20*x**6
# ax.plot(x, y, c="black",linestyle="-")
# y = 50000*x**16
# ax.plot(x, y, c="black",linestyle="-")
# x = np.arange(0.1,0.5,0.0001)
# y = 1000000000*x**30
# ax.plot(x, y, c="black",linestyle="-")

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"erasure rate, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BPOSD order=0 decoder - 50 max. iterations, $|{+}\rangle^{\otimes (N_\text{bulk}-1)}$ gauge",fontsize=7.5)
# ax.set_xlim(right = 0.51)
ax.set_ylim(bottom = 10**(-5.2))
ax.legend(loc=4)
plt.show()

# %%
# new
import matplotlib.pyplot as plt
import numpy as np

ns = [0,1,2,3,4,5]

p_phy_big = [np.linspace(0.05, 0.17, 20).tolist()]*(len(ns))
p_L_big = [[0.12542724609375, 0.1405029296875, 0.15484619140625, 0.169647216796875, 0.18365478515625, 0.196075439453125, 0.209747314453125, 0.222686767578125, 0.23553466796875, 0.2490234375, 0.2626953125, 0.274932861328125, 0.28607177734375, 0.297271728515625, 0.309417724609375, 0.321197509765625, 0.33306884765625, 0.343841552734375, 0.35333251953125, 0.3623046875], [0.08673095703125, 0.102325439453125, 0.116241455078125, 0.1302490234375, 0.146026611328125, 0.150299072265625, 0.177337646484375, 0.194427490234375, 0.210601806640625, 0.229095458984375, 0.246826171875, 0.262969970703125, 0.27972412109375, 0.29803466796875, 0.31597900390625, 0.331573486328125, 0.35174560546875, 0.369171142578125, 0.38787841796875, 0.406158447265625], [0.02728271484375, 0.034759521484375, 0.046142578125, 0.05859375, 0.070556640625, 0.084503173828125, 0.10626220703125, 0.1221923828125, 0.142791748046875, 0.16522216796875, 0.186981201171875, 0.209197998046875, 0.235015869140625, 0.26300048828125, 0.286285400390625, 0.313812255859375, 0.345947265625, 0.371795654296875, 0.405517578125, 0.432952880859375], [0.09051513671875, 0.105682373046875, 0.1234130859375, 0.141448974609375, 0.161773681640625, 0.19012451171875, 0.2215576171875, 0.2550048828125, 0.294219970703125, 0.333648681640625, 0.376251220703125, 0.424072265625, 0.47021484375, 0.517120361328125, 0.56072998046875, 0.5972900390625, 0.62884521484375, 0.659271240234375, 0.685638427734375, 0.705810546875],
           [0.03790283203125, 0.04791259765625, 0.060089111328125, 0.074676513671875, 0.09051513671875, 0.115203857421875, 0.139678955078125, 0.166900634765625, 0.19891357421875, 0.23663330078125, 0.278106689453125, 0.315582275390625, 0.357574462890625, 0.40252685546875, 0.447479248046875, 0.484222412109375, 0.521392822265625, 0.559539794921875, 0.590423583984375, 0.6190185546875],
           [0.036285400390625, 0.045196533203125, 0.057342529296875, 0.072174072265625, 0.086395263671875, 0.10943603515625, 0.1353759765625, 0.162139892578125, 0.193878173828125, 0.232330322265625, 0.2703857421875, 0.313018798828125, 0.35546875, 0.3994140625, 0.446014404296875, 0.482421875, 0.51947021484375, 0.5596923828125, 0.590972900390625, 0.618560791015625]
           ]
# [0.05, 0.056315789473684215, 0.06263157894736843, 0.06894736842105263, 0.07526315789473685, 0.08157894736842106, 0.08789473684210528, 0.09421052631578948, 0.10052631578947369, 0.1068421052631579, 0.11315789473684211, 0.11947368421052633, 0.12578947368421053, 0.13210526315789475, 0.13842105263157894, 0.14473684210526316, 0.15105263157894738, 0.1573684210526316, 0.16368421052631582, 0.17]
# [32768]

# [0.05, 0.056315789473684215, 0.06263157894736843, 0.06894736842105263, 0.07526315789473685, 0.08157894736842106, 0.08789473684210528, 0.09421052631578948, 0.10052631578947369, 0.1068421052631579, 0.11315789473684211, 0.11947368421052633, 0.12578947368421053, 0.13210526315789475, 0.13842105263157894, 0.14473684210526316, 0.15105263157894738, 0.1573684210526316, 0.16368421052631582, 0.17]
# [32768]
num_shots_range = [[2**15]*len(p_phy_big[0])]*(len(ns))

fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","orange","orange","cyan","magenta","yellow"]
strlst = [f"$n={0}$",f"$n={1}$",f"$n={2}$",f"$n={3}$",f"$n={3}$ (100 max iter., OSD_CS order = 5)",f"$n={3}$ (200 max iter., OSD_CS order =10)"]

for ct in range(len(ns)):
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    num_shots = num_shots_range[ct]
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    if ct == 4:
        ax.plot(p_phy, p_L, c=clst[ct],linestyle="dashdot")
        ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct],marker="D")

    elif ct == 5:
        ax.plot(p_phy, p_L, c=clst[ct],linestyle="dashdot")
        ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct],marker="s")

    else:
        ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
        ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])


    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"pauli error rate, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BP decoder - 50 max. iterations, $|{+}\rangle^{\otimes (N_\text{bulk}-1)}$ gauge",fontsize=7.5)
# ax.set_xlim(right = 0.51)
# ax.set_ylim(bottom = 1e-4)
ax.legend(fontsize = 5)
plt.show()

# %%
# new 2
import matplotlib.pyplot as plt
import numpy as np

ns = [0,1,2,3,4]

536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536],
                   [32768, 32768, 32768, 8192, 8192, 8192, 8192, 8192, 8192, 8192],
                   [32768, 32768, 32768, 8192, 8192, 8192, 8192, 8192, 8192, 8192]
                   ]
fig, ax = plt.subplots(dpi=500)

clst = ["red","green","blue","orange","cyan","magenta","yellow"]
strlst = [f"$n={0}$",f"$n={1}$",f"$n={2}$",f"$n={3}$ (200 max iter., OSD_CS order = 10)",f"$n={4}$ (200 max iter., OSD_CS order = 10)"]

for ct in range(len(ns)):
    p_phy = np.array(p_phy_big[ct])
    p_L = np.array(p_L_big[ct])
    num_shots = np.array(num_shots_range[ct])
    std_err = np.sqrt(p_L*(1-p_L)/num_shots)

    # if ct == 4:
    #     ax.plot(p_phy, p_L, c=clst[ct],linestyle="dashdot")
    #     ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct],marker="D")

    # elif ct == 5:
    #     ax.plot(p_phy, p_L, c=clst[ct],linestyle="dashdot")
    #     ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct],marker="s")

    # else:
    ax.plot(p_phy, p_L, c=clst[ct],linestyle="--")
    ax.scatter(p_phy, p_L, c=clst[ct], label=strlst[ct])


    ax.fill_between(p_phy, p_L-std_err, p_L+std_err, alpha=0.2, color=clst[ct])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"pauli error rate, on (boundary) physical qubits")
# ax.set_ylabel(r"central (bulk) logical qubit recovery probability")
ax.set_ylabel(r"central (bulk) logical qubit error rate")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code, BP decoder - 50 max. iterations, $|{+}\rangle^{\otimes (N_\text{bulk}-1)}$ gauge",fontsize=7.5)
# ax.set_xlim(right = 0.51)
# ax.set_ylim(bottom = 1e-4)
ax.legend(fontsize = 5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ratio = [0.0, 0.025, 0.05, 0.10, 0.15, 0.20, 0.30, 0.4, 0.6, 1.0, 1.25, 2]
thres = [0.5, 0.46, 0.425 ,0.37, 0.319, 0.282, 0.225, 0.1925, 0.15, 0.105, 0.087, 0.058]

X = ratio#[0:-2]
Y = thres#[0:-2]
Z = (np.array(X)*np.array(Y)).tolist()

Y = Y+[0]
Z = Z+[0.125]

print(Y)
print(X)
fig, ax = plt.subplots(dpi=500)

clst = ["tab:pink","red","green","blue","orange","cyan","magenta","yellow"]
# strlst = [f"$n={0}$",f"$n={1}$",f"$n={2}$",f"$n={3}$",f"$n={3}$ (100 max iter., OSD_CS order = 5)",f"$n={3}$ (200 max iter., OSD_CS order =10)"]

ax.plot(Y, Z, c=clst[0],linestyle="--")
ax.scatter(Y, Z, c=clst[0])
ax.fill_between(Y, 0, Z, alpha=0.2, color=clst[0])


ax.set_xlabel(r"$p_e$ (erasure rate)")
ax.set_ylabel(r"$p_r$ (pauli error rate)")
ax.grid(True, which="both", ls="-", color='0.65')
ax.set_title(r"$\{4,5\}$ ZX-holographic code error suppresion region",fontsize=9)
# # ax.set_xlim(right = 0.51)
# # ax.set_ylim(bottom = 1e-4)
# ax.legend(fontsize = 5)
plt.show()
# Out:
# [0.5, 0.46, 0.425, 0.37, 0.319, 0.282, 0.225, 0.1925, 0.15, 0.105, 0.087, 0.058, 0]
# [0.0, 0.025, 0.05, 0.1, 0.15, 0.2, 0.3, 0.4, 0.6, 1.0, 1.25, 2]
